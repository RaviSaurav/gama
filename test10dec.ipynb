# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("C:/Users/User/Desktop/BikeSharingData.csv")
df
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# 5          6  2011-01-06       1   0     1        0        4           1
# 6          7  2011-01-07       1   0     1        0        5           1
# 7          8  2011-01-08       1   0     1        0        6           0
# 8          9  2011-01-09       1   0     1        0        0           0
# 9         10  2011-01-10       1   0     1        0        1           1
# 10        11  2011-01-11       1   0     1        0        2           1
# 11        12  2011-01-12       1   0     1        0        3           1
# ...

# %%
#1. Draw scatter plots for casual vs registered users
df.plot(x='casual',y='registered',kind="scatter")
plt.show()

# %%
#2. Draw a histogram showing bike sharing data for various seasons
grid=sns.FacetGrid(df, col='season')
grid.map(plt.hist,'cnt',bins=20)
plt.show()

# %%
#3. Draw a histogram for various weather situations.
plt.hist(df['weathersit'],10,rwidth=0.8)
plt.xlabel('Weather')
plt.ylabel('Frequency')
plt.title('Weather Situation')
plt.show()

# %%
#4. What features affect the bike sharing trends? Why?
df.boxplot(column='cnt', by='season')
plt.show()

# %%
df.boxplot(column='cnt', by='yr')
plt.show()

# %%
df.boxplot(column='cnt', by='mnth')
plt.show()

# %%
df.boxplot(column='cnt', by='holiday')
plt.show()

# %%
df.boxplot(column='cnt', by='weekday')
plt.show()

# %%
df.boxplot(column='cnt', by='workingday')
plt.show()

# %%
df.boxplot(column='cnt', by='weathersit')
plt.show()

# %%
df.plot(x='temp',y='cnt',kind="scatter")
plt.show()

# %%
df.plot(x='atemp',y='cnt',kind="scatter")
plt.show()

# %%
df.plot(x='hum',y='cnt',kind="scatter")
plt.show()

# %%
df.plot(x='windspeed',y='cnt',kind="scatter")
plt.show()

# %%
Features affect the bike sharing trend are: Season, Year, month, Holiday, Weathersit, Temp, Atemp

# %%
#5. Draw a bar chart for bike sharing data for each month.
plt.bar(df['mnth'],df['cnt'])
plt.xlabel("Month")
plt.ylabel("Sharing data")
plt.title("Bike Sharing Trend by Month")
plt.show()

# %%
#6 Draw a pie chart for #5.
from matplotlib.pyplot import pie, axis, show
sums = df.mnth.groupby(df.mnth).sum()
axis('equal');
pie(sums, labels=sums.index);
show()

# %%
#7. Draw a box plot for bike sharing data, What is your analysis of the box plot.
Same as 4th one

# %%
#8. What is the bike sharing data trend on holidays vs week days? Represent visually through graphs.
df.boxplot(column='cnt', by='holiday')
plt.show()

# %%
#9. What is  your analysis  of casual visitors vs registered users?
a=df['casual'].sum()
b=df['registered'].sum()
print(a)
print(b)
The number of registered users are more as compared to casual users. The value of registered users are 4 times more as compared
to casual users
# Out:
# 620017
# 2672662

# %%
#10. For #9, is there a trend for holidays vs week days
df.boxplot(column='casual', by='holiday')
plt.show()
df.boxplot(column='registered', by='holiday')
plt.show()

# %%
Since the registered users are more so they are taking bike on rent more frequently as compared to casual users.
On holidays the registered users are taking more bikes on rent.
On week days the casual users are using more bikes as compared to holidays.
