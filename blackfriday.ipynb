# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('C:/Users/User/Desktop/BlackFriday.csv')
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# 9       1000005  P00274942      M  26-35          20             A
# 10      1000005  P00251242      M  26-35          20             A
# 11      1000005  P00014542      M  26-35          20             A
# 12      1000005  P00031342      M  26-35          20             A
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
table1 = pd.crosstab(df["City_Category"],'Purchase').plot(kind='bar')
plt.show()

# %%
table1 = pd.crosstab(df["Gender"],'Purchase').plot(kind='bar')
plt.show()

# %%
table1 = pd.crosstab(df["Age"],'Purchase').plot(kind='bar')
plt.show()

# %%
table1 = pd.crosstab(df["Occupation"],'Purchase').plot(kind='bar')
plt.show()

# %%
table1 = pd.crosstab(df["Stay_In_Current_City_Years"],'Purchase').plot(kind='bar')
plt.show()

# %%
table1 = pd.crosstab(df["Marital_Status"],'Purchase').plot(kind='bar')
plt.show()

# %%
table1 = pd.crosstab(df["Product_Category_1"],'Purchase').plot(kind='bar')
plt.show()

# %%
table1 = pd.crosstab(df["Product_Category_2"],'Purchase').plot(kind='bar')
plt.show()

# %%
table1 = pd.crosstab(df["Product_Category_3"],'Purchase').plot(kind='bar')
plt.show()

# %%
plt.figure(figsize=(20,10))
corr=df.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns,annot=True)
plt.show()
