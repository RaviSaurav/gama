# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
df = pd.read_csv('C:/Users/User/Desktop/adultt.csv')
df
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 0       90                 ?   77053       HS-grad              9
# 1       82           Private  132870       HS-grad              9
# 2       66                 ?  186061  Some-college             10
# 3       54           Private  140359       7th-8th              4
# 4       41           Private  264663  Some-college             10
# 5       34           Private  216864       HS-grad              9
# 6       38           Private  150601          10th              6
# 7       74         State-gov   88638     Doctorate             16
# 8       68       Federal-gov  422013       HS-grad              9
# 9       41           Private   70037  Some-college             10
# 10      45           Private  172274     Doctorate             16
# 11      38  Self-emp-not-inc  164526   Prof-school             15
# 12      52           Private  129177     Bachelors             13
# ...

# %%
df.head(25)
# Out:
#     age         workclass  fnlwgt     education  education.num  \
# 0    90                 ?   77053       HS-grad              9
# 1    82           Private  132870       HS-grad              9
# 2    66                 ?  186061  Some-college             10
# 3    54           Private  140359       7th-8th              4
# 4    41           Private  264663  Some-college             10
# 5    34           Private  216864       HS-grad              9
# 6    38           Private  150601          10th              6
# 7    74         State-gov   88638     Doctorate             16
# 8    68       Federal-gov  422013       HS-grad              9
# 9    41           Private   70037  Some-college             10
# 10   45           Private  172274     Doctorate             16
# 11   38  Self-emp-not-inc  164526   Prof-school             15
# 12   52           Private  129177     Bachelors             13
# 13   32           Private  136204       Masters             14
# ...

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %%
df['income']=df['income'].apply(lambda x:1 if x=='>50K' else 0)

# %%
df=df[df['workclass']!='?']
df=df[df['occupation']!='?']
df=df[df['native.country']!='?']

# %%
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 1   82   Private  132870       HS-grad              9        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
# 5   34   Private  216864       HS-grad              9       Divorced
# 6   38   Private  150601          10th              6      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 1    Exec-managerial  Not-in-family  White  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
# 5      Other-service      Unmarried  White  Female             0
# 6       Adm-clerical      Unmarried  White    Male             0
#
#    capital.loss  hours.per.week native.country  income
# 1          4356              18  United-States       0
# ...

# %%
grid=sns.FacetGrid(df, col='income',size=4.5)
grid.map(plt.hist,'age',bins=20)
plt.show()

# %%
df.replace(['7th-8th', '10th','11th', '1st-4th', '5th-6th', '12th', '9th', 'Preschool'],['school','school','school','school','school','school','school','school'],inplace=True)

# %%
table1 = pd.crosstab(df["workclass"],'income').plot(kind='bar')
plt.show()

# %%
table1 = pd.crosstab(df["education"],'income').plot(kind='bar')
plt.show()

# %%
table1 = pd.crosstab(df["education.num"],'income').plot(kind='bar')
plt.show()

# %%
df.replace(['Divorced', 'Married-AF-spouse', 
              'Married-civ-spouse', 'Married-spouse-absent', 
              'Never-married','Separated','Widowed'],
             ['not married','married','married','married',
              'not married','not married','not married'], inplace = True)

# %%
table1 = pd.crosstab(df["marital.status"],'income').plot(kind='bar')
plt.show()

# %%
table1 = pd.crosstab(df["occupation"],'income').plot(kind='bar')
plt.show()

# %%
table1 = pd.crosstab(df["relationship"],'income').plot(kind='bar')
plt.show()

# %%
table1 = pd.crosstab(df["race"],'income').plot(kind='bar')
plt.show()

# %%
table1 = pd.crosstab(df["sex"],'income').plot(kind='bar')
plt.show()

# %%
table1 = pd.crosstab(df["native.country"],'income').plot(kind='bar')
plt.show()

# %%
df['native.country'].value_counts()
# Out:
# United-States                 27504
# Mexico                          610
# Philippines                     188
# Germany                         128
# Puerto-Rico                     109
# Canada                          107
# El-Salvador                     100
# India                           100
# Cuba                             92
# England                          86
# Jamaica                          80
# South                            71
# China                            68
# Italy                            68
# Dominican-Republic               67
# Vietnam                          64
# Guatemala                        63
# Japan                            59
# Columbia                         56
# Poland                           56
# Taiwan                           42
# Iran                             42
# Haiti                            42
# Portugal                         34
# Nicaragua                        33
# Peru                             30
# ...

# %%
df['capital.gain'].value_counts()
# Out:
# 0        27624
# 15024      337
# 7688       270
# 7298       240
# 99999      148
# 3103        94
# 5178        91
# 5013        69
# 4386        67
# 3325        53
# 8614        52
# 2174        46
# 10520       43
# 4650        40
# 4064        40
# 14084       39
# 3137        36
# 20051       33
# 27828       32
# 3908        31
# 2829        30
# 594         28
# 6849        26
# 14344       26
# 13550       25
# 4787        22
# 2885        22
# 3411        21
# 1055        21
# 2597        20
#          ...
# 4687         3
# 3418         3
# 2228         3
# 6360         3
# 5721         3
# 2936         3
# 6723         2
# 2961         2
# 3456         2
# 2062         2
# 41310        2
# 3432         2
# 25124        2
# 2009         2
# 7896         2
# 18481        2
# 11678        2
# 2387         1
# 5060         1
# 7978         1
# 2538         1
# 2993         1
# 1173         1
# 1086         1
# 6097         1
# 401          1
# 22040        1
# ...

# %%
df['capital.loss'].value_counts()
# Out:
# 0       28735
# 1902      194
# 1977      162
# 1887      155
# 1848       50
# 1485       45
# 2415       45
# 1740       41
# 1876       39
# 1590       37
# 1672       34
# 1602       34
# 2258       25
# 1564       24
# 1741       23
# 1980       23
# 1669       23
# 2001       21
# 2051       21
# 1579       20
# 1719       20
# 2002       20
# 1408       19
# 1974       18
# 2377       17
# 1504       16
# 1721       16
# 2339       14
# 2179       14
# 1762       13
#         ...
# 1668        3
# 1735        2
# 1755        2
# 2352        2
# 2149        2
# 1138        2
# 810         2
# 3683        2
# 1648        2
# 2238        2
# 1816        2
# 2754        2
# 3900        2
# 974         2
# 2129        2
# 3770        2
# 3004        1
# 2080        1
# 4356        1
# 1944        1
# 2282        1
# 155         1
# 2201        1
# 2457        1
# 1844        1
# 419         1
# 1411        1
# 1539        1
# 2472        1
# 2467        1
# ...

# %%
grid=sns.FacetGrid(df, col='income',size=4.5)
grid.map(plt.hist,'hours.per.week',bins=20)
plt.show()

# %%
df.head(20)
# Out:
#     age  workclass  fnlwgt  education  education.num  marital.status  \
# 1    65          2    6096          4              8               1
# 3    37          2    6564          8              3               1
# 4    24          2   15770          7              9               1
# 5    17          2   13278          4              8               1
# 6    21          2    7296          8              5               1
# 7    57          5    2965          3             15               1
# 8    51          0   19540          4              8               1
# 10   28          2    9020          3             15               1
# 11   21          4    8329          6             14               1
# 12   35          2    5869          2             12               1
# 13   15          2    6293          5             13               1
# 15   29          2    1206          6             14               1
# 16   28          2    9072          8              6               1
# ...

# %%
for col in df:
    b,c=np.unique(df[col],return_inverse=True)
    df[col]=c

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
X = pd.DataFrame(np.c_[df['education.num'],df['workclass'],df['education'],df['age'],df['occupation'],df['race'],df['sex']],columns = ['education.num','workclass','education','age','occupation','race','sex'])
Y = df['income']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state=5)
logreg = LogisticRegression()
logreg.fit(X_train, Y_train)
y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, Y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.80

# %%
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=0)
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, Y_train)
Y_pred = logreg.predict(X_test)
confusion_matrix = confusion_matrix(Y_test, Y_pred)
print(confusion_matrix)
# Out:
# [[6357  404]
#  [1493  795]]

# %%
TN, FP    = confusion_matrix[0, 0], confusion_matrix[0, 1]
FN, TP    = confusion_matrix[1, 0], confusion_matrix[1, 1]

# %%
Accuracy = (float(TP+TN)/float(TP+FP+FN+TN))
print('Accuracy:        ',  round(Accuracy,2) ,"\n")
# Out:
# Accuracy:         0.79

# %%
Precision = (float(TP)/float(TP+FP))
print('Precision:        ',  round(Precision,2) ,"\n")
# Out:
# Precision:         0.66

# %%
Recall = (float(TP)/float(TP+FN))
print ('Recall:        ',round(Recall,2))
# Out:
# Recall:         0.35

# %%
Specificity = (float(TN)/float(TN+FP))
print ('Sepcificity:        ',  round(Specificity,2))
# Out:
# Sepcificity:         0.94

# %%
F1Score = (2*Precision*Recall)/(Precision+Recall)
print ('F1 Score        ',  round(F1Score,2) )
# Out:
# F1 Score         0.46
